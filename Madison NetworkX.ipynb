# %%
# %matplotlib inline
import geopandas

madison = geopandas.read_file('madison3.shp')
madison['center'] = madison.geometry.centroid

# %%
madison.head()
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10 BLOCKCE10          GEOID10      NAME10  \
# 0        55        025    003200      1014  550250032001014  Block 1014
# 1        55        025    001102      2007  550250011022007  Block 2007
# 2        55        025    003200      1015  550250032001015  Block 1015
# 3        55        025    991702      0003  550259917020003  Block 0003
# 4        55        025    000902      2016  550250009022016  Block 2016
#
#   MTFCC10 UR10 UACE10 UATYPE FUNCSTAT10  ALAND10  AWATER10   INTPTLAT10  \
# 0   G5040    U  53200      U          S       56      2324  +43.0765267
# 1   G5040    U  53200      U          S        0      3186  +43.0761736
# 2   G5040    R   None   None          S        0       779  +43.0780683
# 3   G5040    R   None   None          S        0  27281334  +43.0976339
# 4   G5040    U  53200      U          S      382         0  +43.0694833
#
#      INTPTLON10                                           geometry  \
# 0  -089.4214707  POLYGON ((-89.42162999999999 43.076766, -89.42...
# 1  -089.4217068  POLYGON ((-89.422775 43.07408299999999, -89.42...
# 2  -089.4212601  POLYGON ((-89.42147299999999 43.078176, -89.42...
# 3  -089.4184412  POLYGON ((-89.483766 43.09381, -89.48353 43.09...
# 4  -089.4194454  POLYGON ((-89.41968199999999 43.06961, -89.419...
#
#                                          center
# 0  POINT (-89.42143585195828 43.07721897432681)
# 1  POINT (-89.42196230307162 43.07522515737384)
# 2  POINT (-89.42126006660975 43.07806834494028)
# 3  POINT (-89.41843862544388 43.09763121731496)
# 4  POINT (-89.41944540396454 43.06948329794072)

# %%
import itertools, networkx, pandas, shapely

# DE-9IM pattern for shared boundary between two blocks
DE9IM = 'F***1****'

G = networkx.DiGraph()

for (_, row) in madison.iterrows():
    G.add_node(row.GEOID10, geom=row.geometry,
               pos=row.center.coords[0])

_possibles, _candidates, _connections = madison.shape[0]**2, 0, 0
intersections = geopandas.sjoin(madison, madison, how="inner", op='intersects')
boundaries = list()

def shared_linear_boundary(geom1, geom2):
    intersection = geom1.intersection(geom2)
    if intersection.type in ('LineString', 'MultiLineString'):
        return intersection

    if intersection.type in ('Point', 'MultiPoint', 'Polygon', 'MultiPolygon'):
        raise Exception('{}: bad type {}'.format(repr((row1.GEOID10_left, row2.GEOID10)),
                                                 intersection.type))

    if intersection.type == 'GeometryCollection':
        types = {geom.type for geom in intersection.geoms}

        if 'Polygon' in types or 'MultiPolygon' in types:
            raise Exception('{}: type has polygon {}'.format(repr((row1.GEOID10_left, row2.GEOID10)),
                                                     repr(types)))

        if types == {'Point', 'LineString'}:
            lines = [geom for geom in intersection.geoms if geom.type == 'LineString']
            return shapely.geometry.MultiLineString(lines)

        raise Exception('{}: bad type {}'.format(repr((row1.GEOID10_left, row2.GEOID10)),
                                                 intersection.type))

for (id1, row1) in intersections.iterrows():
    _candidates += 1
    geom1, row2 = row1.geometry, madison.loc[row1.index_right]
    geom2 = row2.geometry
    if not geom1.relate_pattern(geom2, DE9IM):
        continue
    _connections += 1
    geomi = shared_linear_boundary(geom1, geom2)
    G.add_edge(row1.GEOID10_left, row2.GEOID10, line=geomi)
    boundaries.append((row1.GEOID10_left, row2.GEOID10, geomi))

# 550250009011018 GeometryCollection
# 550250011022002 GeometryCollection
# 550250011012019 GeometryCollection
# 550250011012002 GeometryCollection
# 550250009021001 GeometryCollection
# 550250009021012 GeometryCollection
# 550250009022002 MultiLineString
# 550250016044002 LineString
# 550250009022012 GeometryCollection
# 550250009022005 GeometryCollection
# 550250009021006 GeometryCollection
# 550250011022001 GeometryCollection
# 550250011012005 GeometryCollection
# 550250009022018 GeometryCollection
# 550250011021001 GeometryCollection
# 550250012003004 GeometryCollection
# 550250009011016 LineString
# 550250009022000 GeometryCollection
# 550250011011012 GeometryCollection
# 550250012003016 LineString
# 550250009022015 GeometryCollection
# 550250011012014 GeometryCollection
# 550250012004004 GeometryCollection
# 550250016064001 GeometryCollection
# 550250011021004 GeometryCollection
# 550250009022007 GeometryCollection
# 550250012004011 LineString
# 550250009012001 GeometryCollection
# 550250009022001 GeometryCollection
# 550250009022010 MultiLineString
# 550250009022011 LineString
# 550250009021002 GeometryCollection
# 550250011011014 GeometryCollection
# 550250012004005 GeometryCollection
# 550250016043001 LineString
# 550250016064000 LineString
# 550250011012001 GeometryCollection
# 550250009022006 GeometryCollection
# 550250032001006 LineString
# 550250011011016 GeometryCollection
# 550250011011002 GeometryCollection
# 550250011011017 GeometryCollection
# 550250011022017 GeometryCollection
# 550250011011003 GeometryCollection
# 550250009012002 GeometryCollection
# 550250011011009 GeometryCollection
# 550250011012018 GeometryCollection
# 550250012004012 LineString
# 550250011012011 GeometryCollection
# 550250016032003 GeometryCollection
# 550250012001003 LineString

# %%
import matplotlib.pyplot as plt

pos = {key: data['pos'] for (key, data) in G.nodes.items()}
labels = {key: key[-5:] for key in G.nodes}
networkx.draw_networkx_nodes(G, pos, node_color='silver', node_size=100)
networkx.draw_networkx_edges(G, pos, edge_color='silver')
networkx.draw_networkx_labels(G, pos, labels, font_color='black', font_size=9)

plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-e81d903162f6> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 pos = {key: data['pos'] for (key, data) in G.nodes.items()}
#       4 labels = {key: key[-5:] for key in G.nodes}
#       5 networkx.draw_networkx_nodes(G, pos, node_color='silver', node_size=100)
#
# <ipython-input-123-e81d903162f6> in <dictcomp>(.0)
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 pos = {key: data['pos'] for (key, data) in G.nodes.items()}
#       4 labels = {key: key[-5:] for key in G.nodes}
#       5 networkx.draw_networkx_nodes(G, pos, node_color='silver', node_size=100)
#
# KeyError: 'pos'

# %%
#madison.plot(figsize=(20, 20), facecolor='#ff9900', edgecolor='white', linewidth=1)

# %%
assignments = [
    '550250016062005', # <-- inside
    '550250016063000', '550250016062004', '550250016063003',
    '550250016062003', '550250016062002', '550250016051003', '550250016051004',
    '550250012001003', # <-- hole
    '550250032001014', '550250011022006' # <-- corner-touch pair
    ]

centers = geopandas.GeoDataFrame([(geoid, G.nodes[geoid]['geom'].representative_point())
                                for geoid in assignments if geoid in G.nodes],
                               columns=['G1', 'geom'],
                               geometry='geom', crs=madison.crs)

centers.to_file('district-centers.shp')

boundary = list(networkx.algorithms.boundary.edge_boundary(G, assignments))
lines = geopandas.GeoDataFrame([(g1, g2, G.edges[(g1, g2)]['line'])
                                for (g1, g2) in boundary],
                               columns=['G1', 'G2', 'geom'],
                               geometry='geom', crs=madison.crs)

lines.to_file('district-lines.shp')
lines
# Out:
#                  G1               G2  \
# 0   550250012001003  550250012004000
# 1   550250012001003  550250012001004
# 2   550250012001003          outside
# 3   550250016063000  550250016064000
# 4   550250016063000  550250016063001
# 5   550250016063000          outside
# 6   550250016063003  550250016063001
# 7   550250016063003  550250016063002
# 8   550250016063003  550250011011019
# 9   550250016063003  550250011011016
# 10  550250016063003  550250011011015
# 11  550250016063003  550250011011013
# 12  550250016063003          outside
# 13  550250032001014  550250011022007
# 14  550250032001014  550250011022002
# 15  550250032001014  550250032001015
# 16  550250032001014  550250032001006
# 17  550250011022006  550250011022007
# 18  550250011022006  550250011022003
# 19  550250011022006  550250032001006
# 20  550250011022006  550250011022012
# 21  550250011022006  550250011022013
# 22  550250011022006  550250011022010
# 23  550250011022006          outside
#
#                                                  geom
# 0   (LINESTRING (-89.400745 43.06476199999999, -89...
# 1   (LINESTRING (-89.397774 43.066547, -89.397773 ...
# 2   LINESTRING (-89.395127 43.066998, -89.395557 4...
# 3   (LINESTRING (-89.39752799999999 43.070907, -89...
# 4   (LINESTRING (-89.39757299999999 43.068959, -89...
# 5   LINESTRING (-89.395905 43.070875, -89.39592499...
# 6   (LINESTRING (-89.39918899999999 43.0694, -89.3...
# 7   (LINESTRING (-89.400886 43.069885, -89.399591 ...
# 8   (LINESTRING (-89.40094099999999 43.06765, -89....
# 9   LINESTRING (-89.400953 43.06822, -89.400944 43...
# 10  LINESTRING (-89.400944 43.068749, -89.40092899...
# 11  (LINESTRING (-89.40092899999999 43.069319, -89...
# 12  LINESTRING (-89.39396699999999 43.067764, -89....
# 13  LINESTRING (-89.42152899999999 43.0765, -89.42...
# 14  (LINESTRING (-89.42120299999999 43.077881, -89...
# 15  LINESTRING (-89.421374 43.07786, -89.421202999...
# 16  (LINESTRING (-89.42162999999999 43.076766, -89...
# 17  (LINESTRING (-89.42167499999999 43.076501, -89...
# 18  (LINESTRING (-89.421369 43.076503, -89.4213829...
# 19  LINESTRING (-89.423266 43.076513, -89.42167499...
# 20  (LINESTRING (-89.418942 43.075031, -89.418947 ...
# 21  LINESTRING (-89.418926 43.075533, -89.418942 4...
# 22  (LINESTRING (-89.418948 43.074224, -89.419135 ...
# 23  (LINESTRING (-89.424156 43.074595, -89.423986 ...

# %%
district_polygons = list(shapely.ops.polygonize(lines.geometry))

polys = geopandas.GeoDataFrame([(poly, )
                                for poly in district_polygons],
                               columns=['geom'],
                               geometry='geom', crs=madison.crs)

polys.to_file('district-polys.shp')
polys
# Out:
#                                                 geom
# 0  POLYGON ((-89.400745 43.06476199999999, -89.40...
# 1  POLYGON ((-89.397773 43.066501, -89.397774 43....
# 2  POLYGON ((-89.42167499999999 43.076501, -89.42...
# 3  POLYGON ((-89.42120299999999 43.077881, -89.42...

# %%
multipoint = centers.geom.unary_union
polys = geopandas.GeoDataFrame([(poly, )
                                for poly in district_polygons
                                if poly.relate_pattern(multipoint, '0********')],
                               columns=['geom'],
                               geometry='geom', crs=madison.crs)

polys.to_file('district-polys.shp')
polys
# Out:
#                                                 geom
# 0  POLYGON ((-89.400745 43.06476199999999, -89.40...
# 1  POLYGON ((-89.42120299999999 43.077881, -89.42...
